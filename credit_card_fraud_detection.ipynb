# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('/content/creditcard.csv')
data
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0           0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...       ...       ...       ...       ...       ...       ...       ...
# 122579  76616  1.512602 -0.949435 -0.219062 -1.638850 -0.856348 -0.465996
# 122580  76616 -2.089968  2.118346  0.262500  1.181082 -1.387323 -0.510274
# 122581  76616 -1.794024  1.580749  0.842719 -1.771693 -0.318492 -0.689972
# 122582  76617  1.241666 -0.167945  0.361075 -0.058731 -0.443949 -0.366504
# 122583  76617  0.796179 -0.992912  0.904255  0.353272 -1.170642  0.161778
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
column=data['Class']

# %%
column.unique()
# Out:
# array([0, 1])

# %%
column.value_counts()
# Out:
# 0    122278
# 1       306
# Name: Class, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122584 entries, 0 to 122583
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    122584 non-null  int64
#  1   V1      122584 non-null  float64
#  2   V2      122584 non-null  float64
#  3   V3      122584 non-null  float64
#  4   V4      122584 non-null  float64
#  5   V5      122584 non-null  float64
#  6   V6      122584 non-null  float64
#  7   V7      122584 non-null  float64
#  8   V8      122584 non-null  float64
#  9   V9      122584 non-null  float64
#  10  V10     122584 non-null  float64
#  11  V11     122584 non-null  float64
#  12  V12     122584 non-null  float64
#  13  V13     122584 non-null  float64
#  14  V14     122584 non-null  float64
#  15  V15     122584 non-null  float64
#  16  V16     122584 non-null  float64
#  17  V17     122584 non-null  float64
#  18  V18     122584 non-null  float64
#  19  V19     122584 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
legit=data[data.Class==0]
fraud=data[data.Class==1]

# %%
legit
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0           0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...       ...       ...       ...       ...       ...       ...       ...
# 122579  76616  1.512602 -0.949435 -0.219062 -1.638850 -0.856348 -0.465996
# 122580  76616 -2.089968  2.118346  0.262500  1.181082 -1.387323 -0.510274
# 122581  76616 -1.794024  1.580749  0.842719 -1.771693 -0.318492 -0.689972
# 122582  76617  1.241666 -0.167945  0.361075 -0.058731 -0.443949 -0.366504
# 122583  76617  0.796179 -0.992912  0.904255  0.353272 -1.170642  0.161778
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
fraud
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 541       406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623       472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920     4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108     6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329     7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...       ...       ...       ...       ...       ...       ...       ...
# 119714  75556 -0.734303  0.435519 -0.530866 -0.471120  0.643214  0.713832
# 119781  75581 -2.866364  2.346949 -4.053307  3.983359 -3.463186 -1.280953
# 120505  75851 -4.793667  3.418911 -5.074445  4.035987 -3.527875 -1.923242
# 120837  75978 -5.140723  3.568751 -5.896245  4.164720 -4.091193 -1.989960
# 122479  76575 -5.622469  3.480623 -6.200677  4.311234 -5.226286 -1.341764
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
print(legit.shape)
# Out:
# (122278, 31)

# %%
print(fraud.shape)
# Out:
# (306, 31)

# %%
legit.Amount.describe()
# Out:
# count    122278.000000
# mean         93.939383
# std         255.255913
# min           0.000000
# 25%           6.840000
# 50%          24.990000
# 75%          84.327500
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     306.000000
# mean      116.376307
# std       235.190770
# min         0.000000
# 25%         1.000000
# 50%        21.500000
# 75%       101.125000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
 legit_sample=legit.sample(n=306)

# %%
legit_sample
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 37347  38916  1.232243 -1.081138  0.167489 -1.125798 -0.502396  1.084296
# 68936  53197 -0.672270 -1.181264  1.760501 -2.306453 -2.148069 -0.309485
# 87580  61747 -0.562385  0.734713  1.373604  1.371717  0.012730  0.119852
# 25624  33693 -0.745720  0.724839  2.015083 -1.422795 -0.262881 -0.849840
# 64191  51070  0.020705 -0.263403  1.216170 -1.302521 -0.805742 -0.451681
# ...      ...       ...       ...       ...       ...       ...       ...
# 6211    7243 -3.353791  3.097561 -0.310649 -0.106147 -1.394202 -0.464351
# 60849  49532  0.898963 -0.731097 -0.680585 -1.519772 -0.148221 -0.711202
# 91481  63488  0.870988 -1.452018 -0.350945 -0.411340 -1.077075 -0.486955
# 37456  38961 -1.661324 -0.742627  1.807060 -0.255916 -0.814885  1.381912
# 62300  50218  1.144704 -0.109821  0.598975  0.891476 -0.680401 -0.462258
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
ndata=pd.concat([legit_sample,fraud],axis=0)
ndata
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 37347   38916  1.232243 -1.081138  0.167489 -1.125798 -0.502396  1.084296
# 68936   53197 -0.672270 -1.181264  1.760501 -2.306453 -2.148069 -0.309485
# 87580   61747 -0.562385  0.734713  1.373604  1.371717  0.012730  0.119852
# 25624   33693 -0.745720  0.724839  2.015083 -1.422795 -0.262881 -0.849840
# 64191   51070  0.020705 -0.263403  1.216170 -1.302521 -0.805742 -0.451681
# ...       ...       ...       ...       ...       ...       ...       ...
# 119714  75556 -0.734303  0.435519 -0.530866 -0.471120  0.643214  0.713832
# 119781  75581 -2.866364  2.346949 -4.053307  3.983359 -3.463186 -1.280953
# 120505  75851 -4.793667  3.418911 -5.074445  4.035987 -3.527875 -1.923242
# 120837  75978 -5.140723  3.568751 -5.896245  4.164720 -4.091193 -1.989960
# 122479  76575 -5.622469  3.480623 -6.200677  4.311234 -5.226286 -1.341764
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
ndata['Class'].value_counts()
# Out:
# 0    306
# 1    306
# Name: Class, dtype: int64

# %%
ndata.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3       V4        V5  \
# Class
# 0      48037.437908 -0.090885 -0.086769  0.735079  0.16721 -0.352779
# 1      39362.620915 -4.796633  3.284157 -5.892262  3.82877 -3.474996
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.120125 -0.122007  0.053217 -0.110295  ...  0.000058  0.025579
# 1     -1.246496 -5.073199  1.262127 -2.252021  ...  0.206244  1.105305
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.119567 -0.016931  0.006244  0.090985  0.050355 -0.003265 -0.010464
# 1     -0.253782 -0.088938 -0.070793  0.185658  0.059459  0.428819  0.068444
#
#            Amount
# Class
# 0       94.920327
# 1      116.376307
#
# [2 rows x 30 columns]

# %%
X=ndata.drop('Class',axis=1)
Y=ndata.Class

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=model.predict(X_test)

# %%
accuracy=accuracy_score(y_test,pred)

# %%
print(accuracy)
# Out:
# 0.8455284552845529

# %%
datan=data.sample(n=1)

# %%
datan
# Out:
#       Time        V1        V2        V3        V4       V5        V6  \
# 4158  3748  1.057204 -1.073779  0.364702 -0.496688 -1.18035 -0.477631
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 4158 -0.66038 -0.036414  0.563564  ... -0.135676 -0.789838 -0.033384
#
#            V24       V25       V26       V27       V28  Amount  Class
# 4158 -0.137456  0.088282 -0.527825 -0.066627  0.028117   180.4      0
#
# [1 rows x 31 columns]

# %%
datan
# Out:
#       Time        V1        V2        V3        V4       V5        V6  \
# 4158  3748  1.057204 -1.073779  0.364702 -0.496688 -1.18035 -0.477631
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 4158 -0.66038 -0.036414  0.563564  ... -0.135676 -0.789838 -0.033384
#
#            V24       V25       V26       V27       V28  Amount  Class
# 4158 -0.137456  0.088282 -0.527825 -0.066627  0.028117   180.4      0
#
# [1 rows x 31 columns]

# %%
datan.Class
# Out:
# 4158    0
# Name: Class, dtype: int64

# %%
samp=datan.drop('Class',axis=1)

# %%
print(model.predict(samp))
# Out:
# [0]
